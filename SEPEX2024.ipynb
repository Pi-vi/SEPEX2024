# %% [markdown]
# # Introdução à Análise e Predição de Séries Temporais em Python

# %% [markdown]
# SEPEX 2024 - Cefet/RJ UnED Angra dos Reis <br>
# Professor Paulo Victor <br>
# Sala 17C

# %% [markdown]
# # Ambientação ao Python e ao Jupyter Notebook

# %% [markdown]
# [Ranking das linguagens de programação mais populares](https://www.tiobe.com/tiobe-index/)
#
# Por que Python?
# * Python é uma linguagem de escrita fácil;
# * É utilizada para diversos propósitos, como por exemplo: construção de aplicativos web, criação de jogos e ciência de dados;
# * Possui uma comumidade ampla e acolhedora.
#
# Python (Piton)??
#
#
# Python é uma **linguagem de alto nível** criada em 1992 por Guido van Rossum. O nome python é uma homenagem ao Monty Python, grupo de humor britânico.

# %%
from IPython.display import IFrame
IFrame('https://www.youtube.com/embed/s0BMfPZCQbI',720,405)
# Out:
#         <iframe
#             width="720"
#             height="405"
#             src="https://www.youtube.com/embed/s0BMfPZCQbI"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# O Jupyter Notebook é um ambiente interativo de computação, neles é possível combinar execução de código, *rich text*, plots e mídia.

# %% [markdown]
# ## Como utilizar o Jupyter Notebook?

# %% [markdown]
# [site do anaconda](anaconda.com)
#
# [Google Colab](colab.research.google.com/)
#
# [binder](https://mybinder.org/)

# %% [markdown]
# ## Tipos de Células:

# %%
print('hello, world')
# Out:
# hello, world

# %%
import antigravity

# %% [markdown]
# Markdown

# %% [markdown]
# ![image.png](attachment:97329bce-7377-4ec3-b66b-747b15af1422.png)

# %% [markdown]
# ## Explorando o Markdown

# %% [markdown]
# ![image.png](attachment:2018a16f-2976-490e-adc4-ff314853da97.png)

# %% [markdown]
# Recursos:
# * Título e subtítulo;
# * negrito;
# * itálico;
# * formatar como código;
# * inserir link;
# * inserir imagem;
# * citação;
# * lista numerada;
# * lista com marcadores;
# * reta horizontal;
# * equações em LaTeX.
# * tabelas

# %% [markdown]
# ### Exercício 1:

# %% [markdown]
# Escrever o seguinte texto:
#
# Olá!
# Estou na SEPEX no CEFET/RJ UnED Angra dos Reis, a instituição de ensino mais legal do mundo!
#
# Eis o porquê de eu gostar daqui:
# 1. xxxxx
# 2. xxxxx
# 3. xxxxx
#
# E além disso, hoje eu aprendi que:
#
# $\int x dx = \dfrac{x^2}{2} + C$

# %% [markdown]
# ### Exercício 2:
#
# Crie a seguinte tabela:

# %% [markdown]
# | Aluno | P1 | Trabalho 1 | P2 | Trabalho 2 |
# | --- | --- | --- | --- | --- |
# | Emma Luna | 6.5 | 5.4 | 7.4 | 7.1 |
# | Nadia Pérez | 9.7 | 8.0 | 3.9 | 10.0 |
# | Tya Vásquez | 5.5 | 9.8 | 4.8 | 3.0 |
# |Rosalva Fuentes | 8.0 | 8.4 | 7.6 | 9.6 |
# | Lucho Rosario | 6.3 | 4.2 | 5.8 | 9.4 |

# %% [markdown]
# from random import gauss

# %% [markdown]
# for i in range(0,30):
#     x =  round(gauss(7, 2),1)
#     if x > 10.0:
#         x =  round(gauss(7, 2),1)
#     print(x)

# %% [markdown]
# # Operações Básicas

# %% [markdown]
# ## Tipos de variáveis
#
# Podemos classificar as variáveis em quatro tipos:
#
# * inteiros (integer)
# * pontos flutantes (float)
# * dados lógicos (boolean)
# * cadeia de caracteres (strings)
#
# Podemos usar o comando type para identificar as variáveis.

# %%
type(5.4)
# Out:
# float

# %% [markdown]
# ### Python como calculadora
#
# Operadores para operações aritméticas básicas:
# * "+" adição <br>
# * "-" subtração <br>
# * "*" multiplicação <br>
# * "/" divisão <br>
# * "**" potenciação.
#
# Podemos ter ainda os operadores:
# * "//" divisão inteira --> Divide o 1º operando (dividendo) pelo 2º operando (divisor) e retorna o valor inteiro sempre arredondado para baixo.
# * "%" módulo --> Retorna o resto da divisão inteira do 1º operando (dividendo) pelo 2º operando (divisor). Em Python este operador sempre retorna o resultado com mesmo sinal do divisor.

# %% [markdown]
# ### Calculadora Científica?

# %% [markdown]
# **importando bibliotecas em python**

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
from numpy import sin,cos,pi,exp

# %%
sin(pi/6)
# Out:
# 0.49999999999999994

# %%
cos(pi/6)
# Out:
# 0.8660254037844387

# %%
from sympy import sin,cos,pi,exp

# %%
sin(pi/6)
# Out:
# 1/2

# %%
cos(pi/6)
# Out:
# sqrt(3)/2

# %%
exp(2)
# Out:
# exp(2)

# %% [markdown]
# ### Operações Booleanas

# %%
5>4
# Out:
# True

# %%
5!=3
# Out:
# True

# %%
True | False
# Out:
# True

# %%
True & False
# Out:
# False

# %% [markdown]
# ## Listas

# %%
lista1 = [2,3,4,1,2,3,5,3]

# %%
min(lista1)
# Out:
# 1

# %%
max(lista1)
# Out:
# 5

# %%
sum(lista1)
# Out:
# 23

# %%
sorted(lista1)
# Out:
# [1, 2, 2, 3, 3, 3, 4, 5]

# %% [markdown]
# ## Dicionários

# %% [markdown]
# # Ciência de Dados

# %% [markdown]
# | Aluno | P1 | Trabalho 1 | P2 | Trabalho 2 |
# | --- | --- | --- | --- | --- |
# | Emma Luna | 6.5 | 5.4 | 7.4 | 7.1 |
# | Nadia Pérez | 9.7 | 8.0 | 3.9 | 10.0 |
# | Tya Vásquez | 5.5 | 9.8 | 4.8 | 3.0 |
# |Rosalva Fuentes | 8.0 | 8.4 | 7.6 | 9.6 |
# | Lucho Rosario | 6.3 | 4.2 | 5.8 | 9.4 |

# %%
import pandas as pd

# %%
Primeiro_nome = ['Emma','Nadia','Tya','Rosalva','Lucho']
Sobrenome = ['Luma', 'Pérez', 'Vásquez', 'Fuentes', 'Rosário']
P1 = [6.5,9.7,5.5,8.0,6.3]
Trabalho_1 = [5.4,8.0,9.8,8.4,4.2]
P2 = [7.4,3.9,4.8,7.6,5.8]
Trabalho_2 = [7.1,10.0,3.0,9.6,9.4]

# %%
df1 = pd.DataFrame({'Primeiro Nome':Primeiro_nome,'Sobrenome':Sobrenome,'P1':P1,'Trabalho_1':Trabalho_1,'P2':P2,'Trabalho 2':Trabalho_2})

# %%
#url = 'https://github.com/Pi-vi/SEPEX2024/blob/main/df1.csv?raw=tre'
#dados = pd.read_csv(url)
url = 'https://github.com/Pi-vi/SEPEX2024/blob/main/df1.xlsx?raw=true'
dados = pd.read_excel(url)

# %%
dados
# Out:
#    Primeiro Nome   Sobrenome   P1  Trabalho 1  P2   Trabalho 2
# 0          Emma         Luna  8.6         4.2  5.1         9.5
# 1         Nadia        Pérez  6.4         6.0  9.2         6.5
# 2           Tya      Vásquez  9.5         8.0  6.3         5.8
# 3       Rosalva      Fuentes  8.2         9.1  8.2         8.9
# 4         Lucho      Rosario  5.7         6.1  8.3         7.4
# 5       Colombo      Narvaez  7.1         5.6  5.3         3.9
# 6          Rosa       Méndez  3.5         4.7  7.2         6.5
# 7      Marcello    Hernández  8.2         6.9  8.2         9.2
# 8     Clementia     Toledano  6.8         7.4  6.0         4.9
# 9         Ducel        Ortíz  6.5         7.9  5.1         5.5
# 10   Laurencius       Rendon  8.8         4.1  9.5         3.4
# 11    Florencio      Bolivar  6.7         1.9  6.7         7.7
# 12           An      De León  6.6         4.8  7.3         8.2
# 13   Cuitlahuac     Fredrick  5.3         5.1  7.8         9.5
# ...

# %%
dados.head()
# Out:
#   Primeiro Nome Sobrenome   P1  Trabalho 1  P2   Trabalho 2
# 0         Emma       Luna  8.6         4.2  5.1         9.5
# 1        Nadia      Pérez  6.4         6.0  9.2         6.5
# 2          Tya    Vásquez  9.5         8.0  6.3         5.8
# 3      Rosalva    Fuentes  8.2         9.1  8.2         8.9
# 4        Lucho    Rosario  5.7         6.1  8.3         7.4

# %%
dados.tail()
# Out:
#    Primeiro Nome Sobrenome   P1  Trabalho 1  P2   Trabalho 2
# 25       Roisia    Estrada  6.1         6.5  6.5         8.8
# 26       Dabora       Soto  8.9         6.5  4.7         8.4
# 27        Balea     Garcia  6.2         8.0  7.7         6.7
# 28        Salud    Obrador  8.4         7.2  7.3         8.5
# 29      Manuelo     Abarca  4.8         5.4  7.8         6.1

# %%
dados.shape
# Out:
# (30, 6)

# %%
dados.describe()
# Out:
#               P1  Trabalho 1        P2   Trabalho 2
# count  29.000000   29.000000  29.000000   29.000000
# mean    6.558621    6.141379   7.158621    7.168966
# std     1.839937    1.815119   1.598105    1.810506
# min     2.900000    1.900000   3.300000    3.400000
# 25%     5.000000    5.000000   6.300000    5.900000
# 50%     6.500000    6.500000   7.300000    7.500000
# 75%     8.200000    7.400000   8.200000    8.800000
# max     9.700000    9.100000   9.900000    9.500000

# %%
dados.columns
# Out:
# Index(['Primeiro Nome', 'Sobrenome', 'P1', 'Trabalho 1', 'P2 ', 'Trabalho 2'], dtype='object')

# %%
dados['P1']
# Out:
# 0     8.6
# 1     6.4
# 2     9.5
# 3     8.2
# 4     5.7
# 5     7.1
# 6     3.5
# 7     8.2
# 8     6.8
# 9     6.5
# 10    8.8
# 11    6.7
# 12    6.6
# 13    5.3
# 14    8.0
# 15    9.7
# 16    4.5
# 17    5.0
# 18    NaN
# 19    4.5
# 20    4.9
# 21    2.9
# 22    4.5
# 23    5.6
# 24    8.3
# 25    6.1
# 26    8.9
# 27    6.2
# 28    8.4
# 29    4.8
# Name: P1, dtype: float64

# %%
dados['P1'].unique
# Out:
# <bound method Series.unique of 0     8.6
# 1     6.4
# 2     9.5
# 3     8.2
# 4     5.7
# 5     7.1
# 6     3.5
# 7     8.2
# 8     6.8
# 9     6.5
# 10    8.8
# 11    6.7
# 12    6.6
# 13    5.3
# 14    8.0
# 15    9.7
# 16    4.5
# 17    5.0
# 18    NaN
# 19    4.5
# 20    4.9
# 21    2.9
# 22    4.5
# 23    5.6
# 24    8.3
# 25    6.1
# 26    8.9
# 27    6.2
# 28    8.4
# 29    4.8
# Name: P1, dtype: float64>

# %%
dados['P1'].value_counts()
# Out:
# P1
# 4.5    3
# 8.2    2
# 8.6    1
# 9.7    1
# 8.4    1
# 6.2    1
# 8.9    1
# 6.1    1
# 8.3    1
# 5.6    1
# 2.9    1
# 4.9    1
# 5.0    1
# 8.0    1
# 6.4    1
# 5.3    1
# 6.6    1
# 6.7    1
# 8.8    1
# 6.5    1
# 6.8    1
# 3.5    1
# 7.1    1
# 5.7    1
# 9.5    1
# 4.8    1
# Name: count, dtype: int64

# %%
dados_org = dados.sort_values(by='Primeiro Nome', ascending=True)

# %%
dados_org
# Out:
#    Primeiro Nome   Sobrenome   P1  Trabalho 1  P2   Trabalho 2
# 22     Abrienda    Contreras  4.5         3.6  8.7         7.6
# 12           An      De León  6.6         4.8  7.3         8.2
# 27        Balea       Garcia  6.2         8.0  7.7         6.7
# 20       Canyon      Herrera  4.9         6.9  8.5         9.4
# 18    Carmelita   De La Vega  NaN         NaN  NaN         NaN
# 15      Choncha         Cruz  9.7         8.8  7.6         5.2
# 8     Clementia     Toledano  6.8         7.4  6.0         4.9
# 5       Colombo      Narvaez  7.1         5.6  5.3         3.9
# 13   Cuitlahuac     Fredrick  5.3         5.1  7.8         9.5
# 26       Dabora         Soto  8.9         6.5  4.7         8.4
# 9         Ducel        Ortíz  6.5         7.9  5.1         5.5
# 0          Emma         Luna  8.6         4.2  5.1         9.5
# 11    Florencio      Bolivar  6.7         1.9  6.7         7.7
# 19        Helio         Ruíz  4.5         7.2  6.3         6.6
# ...

# %%
dados_org = dados_org.reset_index(drop=True)

# %%
dados_org
# Out:
#    Primeiro Nome   Sobrenome   P1  Trabalho 1  P2   Trabalho 2
# 0      Abrienda    Contreras  4.5         3.6  8.7         7.6
# 1            An      De León  6.6         4.8  7.3         8.2
# 2         Balea       Garcia  6.2         8.0  7.7         6.7
# 3        Canyon      Herrera  4.9         6.9  8.5         9.4
# 4     Carmelita   De La Vega  NaN         NaN  NaN         NaN
# 5       Choncha         Cruz  9.7         8.8  7.6         5.2
# 6     Clementia     Toledano  6.8         7.4  6.0         4.9
# 7       Colombo      Narvaez  7.1         5.6  5.3         3.9
# 8    Cuitlahuac     Fredrick  5.3         5.1  7.8         9.5
# 9        Dabora         Soto  8.9         6.5  4.7         8.4
# 10        Ducel        Ortíz  6.5         7.9  5.1         5.5
# 11         Emma         Luna  8.6         4.2  5.1         9.5
# 12    Florencio      Bolivar  6.7         1.9  6.7         7.7
# 13        Helio         Ruíz  4.5         7.2  6.3         6.6
# ...

# %%
#dados_org = dados_org.dropna()

# %% [markdown]
# notas['Nome'] = notas['First Name'] + ' ' + notas['Last Name']
# notas['Nota total P1'] = notas['Notas P1']*0.7 + notas['Seminário']*0.3
# notas['Nota total P2'] = notas['P2'
#                    ]*0.7 + notas['Seminários P2']*0.3
# notas['média final'] = (notas['Nota total P1'] + notas['Nota total P2'])/2

# %%
dados_org['Nome'] = dados_org['Primeiro Nome'] + ' ' + dados_org['Sobrenome']

# %%
dados_org['Média'] = (dados_org['P1']*0.7 + dados_org['Trabalho 1']*0.3 + dados_org['P2 ']*0.7 + dados_org['Trabalho 2']*0.3)/2

# %%
def verific(media):
    if media >= 7:
        return 'Aprovado'
    else:
        return 'Reprovado'

# %%
dados_org['Status'] = dados_org['Média'].apply(verific)

# %%
dados_org
# Out:
#    Primeiro Nome   Sobrenome   P1  Trabalho 1  P2   Trabalho 2  \
# 0      Abrienda    Contreras  4.5         3.6  8.7         7.6
# 1            An      De León  6.6         4.8  7.3         8.2
# 2         Balea       Garcia  6.2         8.0  7.7         6.7
# 3        Canyon      Herrera  4.9         6.9  8.5         9.4
# 4     Carmelita   De La Vega  NaN         NaN  NaN         NaN
# 5       Choncha         Cruz  9.7         8.8  7.6         5.2
# 6     Clementia     Toledano  6.8         7.4  6.0         4.9
# 7       Colombo      Narvaez  7.1         5.6  5.3         3.9
# 8    Cuitlahuac     Fredrick  5.3         5.1  7.8         9.5
# 9        Dabora         Soto  8.9         6.5  4.7         8.4
# 10        Ducel        Ortíz  6.5         7.9  5.1         5.5
# 11         Emma         Luna  8.6         4.2  5.1         9.5
# 12    Florencio      Bolivar  6.7         1.9  6.7         7.7
# 13        Helio         Ruíz  4.5         7.2  6.3         6.6
# ...
